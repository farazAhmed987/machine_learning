# %% [markdown]
# <a href="https://colab.research.google.com/github/farazAhmed987/machine_learning/blob/main/student_result_predictor(logistic_regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/student_exam_dataset.csv")

df
# Out:
#      student_id  study_hours_per_day  attendance_percent  prev_gpa  \
# 0             1                  4.3                  55      2.80
# 1             2                  4.1                  98      1.27
# 2             3                  4.5                  57      3.38
# 3             4                  4.9                  52      3.55
# 4             5                  6.9                  41      2.41
# ..          ...                  ...                 ...       ...
# 195         196                  8.0                  48      1.70
# 196         197                  1.2                  61      2.54
# 197         198                  4.6                  71      3.20
# 198         199                  1.8                  89      2.45
# 199         200                  0.9                  92      2.56
#
#      sleep_hours  assignments_completed  passed
# 0            4.9                      2       0
# 1            7.2                      3       0
# ...

# %%
# df.head()
# df.info()
# df.shape

# %%
#data preprocessing
df = df.iloc[:,1:]
df
# Out:
#      study_hours_per_day  attendance_percent  prev_gpa  sleep_hours  \
# 0                    4.3                  55      2.80          4.9
# 1                    4.1                  98      1.27          7.2
# 2                    4.5                  57      3.38          8.2
# 3                    4.9                  52      3.55          5.5
# 4                    6.9                  41      2.41          5.9
# ..                   ...                 ...       ...          ...
# 195                  8.0                  48      1.70          6.5
# 196                  1.2                  61      2.54          6.3
# 197                  4.6                  71      3.20          6.2
# 198                  1.8                  89      2.45          8.8
# 199                  0.9                  92      2.56          6.7
#
#      assignments_completed  passed
# 0                        2       0
# 1                        3       0
# 2                        6       1
# ...

# %%
#feature selection
from sklearn.feature_selection import SelectKBest, mutual_info_classif, chi2
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('/student_exam_dataset.csv')
X = df[['study_hours_per_day','attendance_percent','prev_gpa','sleep_hours','assignments_completed']]
y = df['passed']

# Mutual information
mi = mutual_info_classif(X, y, random_state=42)
mi_scores = pd.Series(mi, index=X.columns).sort_values(ascending=False)
print("Mutual Information:\n", mi_scores)

# Pearson correlation
corr = X.corrwith(y).abs().sort_values(ascending=False)
print("\nCorrelation with target:\n", corr)

# Select top 3 features
selector = SelectKBest(mutual_info_classif, k=3)
selector.fit(X, y)
selected = X.columns[selector.get_support()].tolist()
print("\nTop 3 features selected:", selected)
# Out:
# Mutual Information:
#  prev_gpa                 0.132481
# study_hours_per_day      0.090552
# attendance_percent       0.000000
# sleep_hours              0.000000
# assignments_completed    0.000000
# dtype: float64
#
# Correlation with target:
#  study_hours_per_day      0.425486
# prev_gpa                 0.363220
# assignments_completed    0.247176
# sleep_hours              0.227275
# attendance_percent       0.169855
# dtype: float64
#
# Top 3 features selected: ['study_hours_per_day', 'prev_gpa', 'assignments_completed']

# %%
df=df.drop('sleep_hours',axis = 1)
df=df.drop('attendance_percent',axis = 1)
df
# Out:
#      student_id  study_hours_per_day  prev_gpa  assignments_completed  passed
# 0             1                  4.3      2.80                      2       0
# 1             2                  4.1      1.27                      3       0
# 2             3                  4.5      3.38                      6       1
# 3             4                  4.9      3.55                      8       1
# 4             5                  6.9      2.41                      4       0
# ..          ...                  ...       ...                    ...     ...
# 195         196                  8.0      1.70                      1       0
# 196         197                  1.2      2.54                      8       1
# 197         198                  4.6      3.20                      3       1
# 198         199                  1.8      2.45                      6       1
# 199         200                  0.9      2.56                      7       1
#
# [200 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
#extract input and output cols
x=df.iloc[:,:-1]
y=df.iloc[:,-1]





x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=42)
#scale values
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)
#model selection
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
y_predict = model.predict(x_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict)
# Out:
# 0.85
